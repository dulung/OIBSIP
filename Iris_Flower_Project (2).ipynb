# %% [markdown]
# # **IRIS FLOWER CLASSIFICATION**

# %% [markdown]
# ##Data Collection

# %% [markdown]
# *We upload the csv file*

# %% [markdown]
# *We import pandas library*

# %%
import pandas as pd

# %% [markdown]
# *We read the csv file and store the data in a dataframe*

# %%
df=pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ##Data Cleaning

# %% [markdown]
# *We are checking if there is any null value present in the dataset*

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ##Data Visualization and Analysis

# %% [markdown]
# *We are importing seaborn and mathplotlib libraries and then computing the corelation matrix and plotting the heatmap to understand the correlation between each of them*

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Compute the correlation matrix
corr_matrix = df.drop(['Id','Species'],axis=1).corr()
# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ***By analyzing the heat map we can infer the following:***
#
# *   the SepalLengthCm has negative correlation with SepalWidthCm
# *   the SepalLengthCm has positive correlation with
# PetalLengthCm and PetalWidthCm
# *   the SepalWidthCm has negative correlation with SepalLengthCm, PetalLengthCm and PetalWidthCm
# *   the PetalLengthCm and PetalWidthCm has negative correlation with SepalWidthCm
# *   the PetalLengthCm has postive correlation with SepalLengthCm and PetalWidth
# *   the PetalWidthCm has positive correlation with
# SepalLengthCm and PetalLengthCm

# %% [markdown]
# ##Data Preparation

# %% [markdown]
# *We convert the Species column contents into numerical values*

# %%
df['Species'] = df['Species'].map({'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2})
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %% [markdown]
# *We are identifying the dependent and indepedent columns and storing the dependent values in y and the independent values in X*

# %%
X=df.drop(['Id','Species'],axis=1)
y=df['Species']

# %% [markdown]
# *We are dividing the data into training and testing sets*

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# ##Model Builiding and Evaluation

# %% [markdown]
# *For Model Building I have used the algorithm Logistic Regression*

# %%
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression(max_iter=500)
log_reg.fit(X_train,y_train)
print("Accuracy:",log_reg.score(X_test,y_test))
# Out:
# Accuracy: 1.0
