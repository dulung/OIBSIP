# %% [markdown]
# # **SPAM EMAIL DETECTION WITH MACHINE LEARNING**

# %% [markdown]
# ##Data Collection

# %% [markdown]
# *We upload the csv file*

# %% [markdown]
# *We import pandas*

# %%
import pandas as pd

# %% [markdown]
# We read the file and store the data in a dataframe

# %%
df = pd.read_csv("Spam Email Detection - spam.csv")
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will �_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %% [markdown]
# ##Data Cleaning

# %% [markdown]
# *We are dropping the unnecessary columns from the dataframe*

# %%
df = df.drop(["Unnamed: 2","Unnamed: 3","Unnamed: 4"], axis=1)
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will �_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# *We are renaming the columns to make it more understandable*

# %%
df.rename(columns={"v1":"Label","v2":"Message"}, inplace=True)
df
# Out:
#      Label                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will �_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# *We are checking if there is any null value present in the dataset*

# %%
df.isnull().sum()
# Out:
# Label      0
# Message    0
# dtype: int64

# %% [markdown]
# ##Data Preperation

# %% [markdown]
# *We convert the Label column contents into numerical values.
# We are identifying the dependent and indepedent columns and storing the dependent values in y and the independent values in X*

# %%
df['Label']=df['Label'].map({'spam':1,'ham':2})
from sklearn.feature_extraction.text import CountVectorizer
vector = CountVectorizer()
X = vector.fit_transform(df['Message'])
y = df['Label']
df
# Out:
#       Label                                            Message
# 0         2  Go until jurong point, crazy.. Available only ...
# 1         2                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         2  U dun say so early hor... U c already then say...
# 4         2  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567      1  This is the 2nd time we have tried 2 contact u...
# 5568      2              Will �_ b going to esplanade fr home?
# 5569      2  Pity, * was in mood for that. So...any other s...
# 5570      2  The guy did some bitching but I acted like i'd...
# 5571      2                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# *We are dividing the data into training and testing sets*

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# ##Model Building and Evaluation

# %% [markdown]
# *For Model Building I have used the algorithm Logistic Regression*

# %%
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression()
log_reg.fit(X_train,y_train)
print("Accuracy:",log_reg.score(X_test,y_test))
# Out:
# Accuracy: 0.9829596412556054

# %% [markdown]
# ##Model Deployment

# %% [markdown]
# **Test Inputs**
#
# Congratulations! You've won a $1,000 gift card! Click here to claim your prize!
#
# Hi Mom, just wanted to check in and see how you're doing. Talk to you soon!
#
# Meeting Reminder: Project Update Meeting at 10:00 AM tomorrow in Conference Room B.
#
# Thank you for your purchase! Your order #12345 has been shipped and will arrive within 3-5 business days.
#
# You've been selected to receive a FREE iPhone 15! Click here to claim your prize before it’s too late!

# %% [markdown]
# *We give test inputs to predict whether the email is spam or ham*

# %%
email = []
n=int(input('Enter the number of emails to be predcited: '))
print('Enter',n,'emails')
for i in range(n):
  email.append(input())
email_transformed = vector.transform(email)
predictions = log_reg.predict(email_transformed)
d={1:'spam',2:'ham'}
for i in predictions:
  print(d[i])
# Out:
# Enter the number of emails to be predcited: 5
# Enter 5 emails
# Congratulations! You've won a $1,000 gift card! Click here to claim your prize!
# Hi Mom, just wanted to check in and see how you're doing. Talk to you soon!
# Meeting Reminder: Project Update Meeting at 10:00 AM tomorrow in Conference Room B.
# Thank you for your purchase! Your order #12345 has been shipped and will arrive within 3-5 business days.
# You've been selected to receive a FREE iPhone 15! Click here to claim your prize before it’s too late!
# spam
# ham
# ham
# ham
# spam
